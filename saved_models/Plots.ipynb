# plt.figure(1)
# plt.suptitle('Validation accuracy learning curve', fontsize=20)
# plt.xlabel('epochs', fontsize=14)
# plt.ylabel('validation accuracy', fontsize=14)
# plt.plot(densenet_val_acc, label='Densenet')
# plt.plot(inceptionV3_val_acc, label='InceptionV3')
# plt.plot(vgg16_val_acc, label='VGG16')
# plt.plot(vgg19_val_acc, label='VGG19')
# plt.plot(xception_val_acc, label='Xception')
# plt.xticks(np.arange(0, epochs + epochs/10, epochs/10))
# plt.legend(loc="lower right")
# plt.savefig("val_accuracy.png", dpi=300)


# plt.figure(2)
# plt.suptitle('Validation loss learning curve', fontsize=20)
# plt.xlabel('epochs', fontsize=14)
# plt.ylabel('validation loss', fontsize=14)
# plt.plot(densenet_val_loss, label='Densenet')
# plt.plot(inceptionV3_val_loss, label='InceptionV3')
# plt.plot(vgg16_val_loss, label='VGG16')
# plt.plot(vgg19_val_loss, label='VGG19')
# plt.plot(xception_val_loss, label='Xception')
# plt.xticks(np.arange(0, epochs + epochs/10, epochs/10))
# plt.legend(loc="upper right")
# plt.savefig("val_loss.png", dpi=300)

# %%
epochs = 20

densenet_acc = [0.39106146, 0.47346368, 0.51955307, 0.52793294, 0.57122904, 0.5265363, 0.54469275, 0.5405028, 0.5642458, 0.5502793, 0.58938545, 0.58798885, 0.54888266, 0.5865922, 0.56703913, 0.5642458, 0.5796089, 0.5642458, 0.57681566, 0.57681566]
densenet_loss = [96.65555775232156, 10.196940477999895, 2.239463561074028, 2.0109361110452832, 1.5276458679630769, 1.682244848272654, 1.3255196273659862, 1.3391179848649648, 1.405492614767405, 1.314421897826914, 1.1726795404982966, 1.1600080290653185, 1.17645574548391, 1.047460270827043, 1.3250603844000641, 1.114833627999162, 1.5724945194894375, 1.3485814719226774, 1.2122420232389226, 1.102461777252858]

inceptionV3_acc = [0.3198324, 0.46927375, 0.5, 0.49022347, 0.53072625, 0.5265363, 0.5377095, 0.53072625, 0.5363129, 0.5293296, 0.52793294, 0.49301675, 0.5027933, 0.51256984, 0.5432961, 0.53910613, 0.5349162, 0.5432961, 0.53351957, 0.52793294]
inceptionV3_loss = [86.93124389781632, 3.2647243345249963, 2.0870420473247933, 1.8335549438465908, 1.5869339877666708, 1.4511166824308854, 1.4053691911963777, 1.3891175805523408, 1.3607213810169496, 1.3423957365185188, 1.3987361888645748, 1.7001206135616622, 1.4173127279601283, 1.9306450043310666, 1.4644104102470354, 1.2614725834830514, 1.325208107852403, 1.2588129353256865, 1.2757485292477315, 1.2810092605026075]

vgg16_acc = [0.4316, 0.6131, 0.6564, 0.7123, 0.7374, 0.7528, 0.8087, 0.8059, 0.8478, 0.8464, 0.8380, 0.8394, 0.8645, 0.8575, 0.8506, 0.8771, 0.8911, 0.8827, 0.8939, 0.9022]
vgg16_loss = [47.2884, 12.4020, 8.3973, 4.5814, 3.8387, 2.9693, 2.0910, 1.7825, 1.3205, 1.4222, 1.4335, 1.0472, 0.9671, 0.9550, 0.9851, 1.2237, 0.5025, 0.5325, 0.8225, 0.6256]

vgg19_acc = [0.47206703, 0.5977654, 0.6522346, 0.6885475, 0.6927374, 0.73044693, 0.74581003, 0.7709497, 0.74441344, 0.7849162, 0.8324022, 0.8365922, 0.8449721, 0.8603352, 0.82821226, 0.8840782, 0.8798883, 0.8687151, 0.8868715, 0.8798883]
vgg19_loss = [47.255383595408006, 11.520811980417552, 7.858244291439069, 4.743463346125495, 3.5473016861620668, 2.832006389618586, 2.8812881927500222, 2.423575146442344, 1.8126549429296615, 1.459556405645842, 0.9800038353220756, 0.8945577251607834, 1.0459681391752251, 0.7625317498625324, 0.9332609130313501, 0.6458768443877251, 0.7288396355660675, 0.7241182869338293, 0.6808335655639579, 0.8408126545925761]

xception_acc = [0.38128492, 0.4162011, 0.5209497, 0.51955307, 0.5684357, 0.57821226, 0.599162, 0.6075419, 0.6187151, 0.60614526, 0.62150836, 0.6298883, 0.6592179, 0.6480447, 0.64944136, 0.6592179, 0.6773743, 0.67318434, 0.6662011, 0.68296087]
xception_loss = [38.21715425912228, 5.539977655480694, 2.340624403687163, 1.7086941456661544, 1.6342819689372399, 1.494831197754631, 1.4823507416847699, 1.320355990079528, 1.267670908786731, 1.2374035016784455, 1.1776873892246011, 1.206584573458027, 1.0727667262434293, 1.0592371035554555, 1.2096733027996298, 1.0703170902236214, 0.8949322270114994, 0.9128807008932422, 1.0276941450614503, 0.924015509849154]


plt.figure(1)
plt.suptitle('Training accuracy learning curve', fontsize=20)
plt.xlabel('epochs', fontsize=14)
plt.ylabel('training accuracy', fontsize=14)
plt.plot(densenet_acc, label='Densenet')
plt.plot(inceptionV3_acc, label='InceptionV3')
plt.plot(vgg16_acc, label='VGG16')
plt.plot(vgg19_acc, label='VGG19')
plt.plot(xception_acc, label='Xception')
plt.xticks(np.arange(0, epochs + epochs/10, epochs/10))
plt.legend(loc="lower right")
plt.savefig("train_accuracy.png", dpi=300)


plt.figure(2)
plt.suptitle('Training loss learning curve', fontsize=20)
plt.xlabel('epochs', fontsize=14)
plt.ylabel('training loss', fontsize=14)
plt.plot(densenet_loss, label='Densenet')
plt.plot(inceptionV3_loss, label='InceptionV3')
plt.plot(vgg16_loss, label='VGG16')
plt.plot(vgg19_loss, label='VGG19')
plt.plot(xception_loss, label='Xception')
plt.xticks(np.arange(0, epochs + epochs/10, epochs/10))
plt.legend(loc="upper right")
plt.savefig("train_loss.png", dpi=300)
